# %% [markdown]
# # **`Inatel - C24 (Inteligência Artificial) - 2026/2`**

# %% [markdown]
# # <font color='green'><u>**Atividade 01 - Análise Exploratória de Dados e Transformações**</u></font>

# %% [markdown]
# ## <font color='#2D9CDB'>**LEIA ATENTAMENTE AS INSTRUÇÕES A SEGUIR**</font>
# - <font color='red'>**A atividade deverá ser resolvida em grupos de até 3 integrantes.**</font>
# - Importe este notebook no [Google Colab](https://colab.research.google.com/) para resolver os exercícios;
# - Consulte o material disponibilizado pelo(a) professor(a) para revisar os conceitos;
# - Utilize os recursos disponíveis na Internet (documentações e artigos científicos) para complementar seus estudos;
# - <font color='red'>**A ATIVIDADE DEVERÁ SER REALIZADA _AO VIVO_ COM O [MONITOR](mailto:matheus.botelho@ges.inatel.br), EM UM DOS SEGUINTES HORÁRIOS:**</font>
#
# | Monitor                       | Dia           | Hora                       | Local                                                      |
# |-------------------------------|---------------|----------------------------|----------------------------------------------------------- |
# | Matheus Botelho Sampaio Netto | <font color='#2D9CDB'>Terça-feira</font>   | <font color='#2D9CDB'>17:30</font> | Teams (ao vivo)       |
# | Matheus Botelho Sampaio Netto | <font color='#2D9CDB'>Quarta-feira</font>   | <font color='#2D9CDB'>17:30</font> | Teams (ao vivo)       |
# | Matheus Botelho Sampaio Netto | <font color='LightSeaGreen'>Sábado</font>  | <font color='LightSeaGreen'>13:30</font> | Teams (ao vivo) |
#
# - <font color='red'>**NÃO**</font> remova as células de Código já presentes neste notebook;
# - <font color='red'>**NÃO**</font> modifique as células de Markdown (em <font color='LightSeaGreen'><u>verde</font> ou <font color='#2D9CDB'><u>azul</u></font>) presentes neste notebook;
# - Após cada questão, há uma célula para você implementar e responder a questão;
# - É permitido adicionar mais células (de código ou markdown) antes da próxima pergunta;
# - Caso precise utilizar bibliotecas que não estão instaladas nativamente no Colab, inclua uma célula de código com o comando de instalação.</font>
#   - Exemplo: `!pip install nome_da_biblioteca`

# %% [markdown]
# - <font color='magenta'>**A ENTREGA É COMPOSTA POR DOIS ITENS, AMBOS ANEXADOS À TAREFA DO TEAMS:**</font>
#   - <font color='red'>**1) O notebook com a resolução**</font>, baixado do [Google Colab](https://colab.research.google.com/) com a saída de todas as células preservada;
#   - <font color='red'>**2) Um vídeo de apresentação de até 15 minutos**</font>, no qual o grupo explica as resoluções de forma concisa.
#     - <font color='red'>**Todos os integrantes devem participar**</font>, dividindo as questões entre si;
#     - Questões de implementação direta podem ser apresentadas em bloco;
#     - As questões dissertativas devem ser justificadas individualmente, explicando o porquê de cada escolha e não apenas o que foi feito;
#     - Mantenha o notebook visível na tela durante a apresentação.
#   - <font color='red'>**A entrega deve ser feita por apenas um integrante da equipe**</font>, em nome de todo o grupo. Os demais não devem submeter a tarefa;
#   - <font color='red'>**Identifique todos os integrantes**</font> (nome completo e matrícula) na célula de markdown abaixo.
#   - <font color='red'>**NÃO**</font> publique este notebook, sua resolução ou o vídeo em repositórios ou plataformas públicas, nem os compartilhe com outros grupos;
#       - Se desejar versionar o trabalho, utilize um repositório <font color='red'>**privado**.

# %% [markdown]
# - <font color='magenta'>**SOBRE O USO DE FERRAMENTAS DE IA GENERATIVA:**</font>
#   - O uso é <font color='red'>**permitido**</font> como apoio ao estudo, para esclarecer conceitos, consultar documentação e revisar código;
#   - Se utilizar IA em alguma questão, registre em uma célula de markdown <font color='red'>**quais questões**</font>, qual ferramenta foi usada e para quê.
#       - Declarações genéricas, como "usei IA na atividade toda", não atendem a este requisito;
#   - <font color='red'>**O uso identificado de IA sem o devido apontamento acarretará a desconsideração das questões envolvidas.**</font>
#       - A declaração não reduz a nota; a omissão, sim;
#   - Declarar o uso de IA não isenta o grupo de compreender e justificar a resolução;
#   - <font color='red'>**No vídeo, o grupo deve justificar as escolhas feitas, e não apenas narrar o código.**</font>
#       - Sempre que uma questão admitir mais de um caminho, explique por que o grupo optou por aquele;
#   - Todos os integrantes devem falar, e cada um deve comentar ao menos uma questão;
#   - Respostas que o grupo não conseguir justificar serão desconsideradas na correção.

# %% [markdown]
# ## <font color='#2D9CDB'>**INTEGRANTES DO GRUPO**</font>
#
# | Nome                          | Matrícula | E-mail                  |
# |-------------------------------|-----------|-------------------------|
# | Nome 1                        | XXX       | email_1@curso.inatel.br |
# | Nome 2                        | YYY       | email_2@curso.inatel.br |
# | Nome 3                        | ZZZ       | email_3@curso.inatel.br |

# %% [markdown]
# ## <font color='LightSeaGreen'><u>**Preparação**</u></font>

# %%
# !pip install pandas numpy matplotlib seaborn scikit-learn ucimlrepo

# %%
from pprint import pprint

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler
from ucimlrepo import fetch_ucirepo

# %% [markdown]
# # <font color='green'><u>**Parte 1 - Análise Exploratória de Dados (EDA)**</u></font>

# %% [markdown]
# ## <font color='LightSeaGreen'><u>**1.1 Conjuntos de Dados**</u></font>
# ### <font color='LightSeaGreen'>Não altere o conteúdo da célula a seguir.</font>

# %%
ds = fetch_ucirepo(id=942)

X = ds.data.features 
y = ds.data.targets

df = pd.concat([X, y], axis='columns')

# %% [markdown]
# ### <font color='#2D9CDB'>Q1: Acesse o link indicado e, em um único parágrafo, descreva brevemente o dataset, incluindo: data de criação, domínio de aplicação, objetivo da base de dados e o tipo de informações que ela contém.
# - #### <font color='#2D9CDB'>S., B. & Nagapadma, R. (2023). RT-IoT2022. UCI Machine Learning Repository. https://doi.org/10.24432/C5P338.</font>

# %% [markdown]
# ### <font color='#2D9CDB'>Q2: Exiba 10 amostras aleatórias do conjunto de dados.</font>

# %% [markdown]
# ### <font color='#2D9CDB'>Q3: Quantas amostras o conjunto de dados possui?</font>

# %% [markdown]
# ### <font color='#2D9CDB'>Q4: Quantas características o conjunto de dados possui?</font>

# %% [markdown]
# ### <font color='#2D9CDB'>Q5: O conjunto de dados possui características numéricas? Se sim, escreva seu(s) nome(s) e classifique-a(s) como contínua(s) e/ou discreta(s).</font>
# - #### <font color='#2D9CDB'>Observação: considere que uma caraterística numérica é discreta se possui menos que 50 valores únicos.</font>

# %% [markdown]
# ### <font color='#2D9CDB'>Q6: O conjunto de dados possui características categóricas? Se sim, escreva seu(s) nome(s) e sua(s) quantidade(s) de valores únicos.</font>

# %% [markdown]
# ## <font color='LightSeaGreen'><u>**1.2 Estatística Descritiva Básica**</u></font>

# %% [markdown]
# ### <font color='#2D9CDB'> Q7: Escolha uma característica numérica do conjunto de dados. Escreva seu nome a seguir.</font>

# %% [markdown]
# ### <font color='#2D9CDB'> Q8: Calcule e mostre suas Medidas de Tendência Central (média, mediana e moda).</font>

# %% [markdown]
# ### <font color='#2D9CDB'> Q9: Calcule e mostre suas Medidas de Dispersão (mínimo, máximo e amplitude).</font>

# %% [markdown]
# ## <font color='LightSeaGreen'><u>**1.3 Análise Univariada**</u></font>

# %% [markdown]
# ### <font color='#2D9CDB'> Q10: Escolha uma característica categórica do conjunto de dados. Escreva seu nome a seguir.</font>

# %% [markdown]
# ### <font color='#2D9CDB'> Q11: Crie e exiba uma Tabela de Frequência e/ou um Gráfico de Barras para a característica escolhida.</font>

# %% [markdown]
# ### <font color='#2D9CDB'> Q12: Escolha uma característica numérica do conjunto de dados. Escreva seu nome a seguir.</font>

# %% [markdown]
# ### <font color='#2D9CDB'> Q13: Crie e exiba um Histograma e/ou uma Estimativa de Densidade por Kernel (KDE) para a característica escolhida.</font>

# %% [markdown]
# ## <font color='LightSeaGreen'><u>**1.4 Análise Bivariada**</u></font>

# %% [markdown]
# ### <font color='#2D9CDB'> Q14: Escolha duas características do conjuntos de dados. Escreva seus nome a seguir.</font>

# %% [markdown]
# ### <font color='#2D9CDB'> Q15: De acordo com os tipos das características escolhidas, produza pelo menos uma visualização de análise bivariada.</font>

# %% [markdown]
# ## <font color='LightSeaGreen'><u>**1.5 Identificação de Problemas nos Dados**</u></font>

# %% [markdown]
# ### <font color='#2D9CDB'> Q16: Inspecione o conjuntos de dados para verificar se há:</font>
# - #### <font color='#2D9CDB'> Dados Ausentes;</font>
# - #### <font color='#2D9CDB'> Valores Atípicos (via IQR);</font>
# - #### <font color='#2D9CDB'> Valores Duplicados;</font>
# ### <font color='#2D9CDB'> Reporte sua(s) descoberta(s) a seguir.</font>

# %% [markdown]
# ### <font color='#2D9CDB'> Q17: Caso um problema tenha sido encontrado, proponha uma solução para ele.</font>
# ### <font color='#2D9CDB'> Exiba o conjunto de dados antes e depois da solução, enfatizando as mudanças.</font>

# %% [markdown]
# ## <font color='LightSeaGreen'><u>**1.6 Correlação Simples**</u></font>

# %% [markdown]
# ### <font color='#2D9CDB'> Q18: Escolha duas características numéricas do conjuntos de dados. Escreva seus nomes a seguir.</font>

# %% [markdown]
# ### <font color='#2D9CDB'> Q19: Calcule e exiba o Coeficiente de Correlação de Pearson ($r$) entre elas.</font>

# %% [markdown]
# ### <font color='#2D9CDB'> Q20: Interprete o coeficiente de correlação, em termos de sinal e magnitude.</font>

# %% [markdown]
# # <font color='green'><u>**Parte 2 - Transformações dos Dados (Pré-processamento)**</u></font>

# %% [markdown]
# ## <font color='LightSeaGreen'><u>**2.1 Conjuntos de Dados**</u></font>
# ### <font color='LightSeaGreen'>Não altere o conteúdo da célula a seguir.</font>

# %%
ds = fetch_ucirepo(id=468)

_X_uci = ds.data.features
_y_uci = ds.data.targets

df = pd.concat([_X_uci, _y_uci], axis='columns')

# %% [markdown]
# ### <font color='#2D9CDB'>Q21: Acesse o link indicado e, em um único parágrafo, descreva brevemente o dataset, incluindo: domínio de aplicação, objetivo da base de dados e o tipo de informações que ela contém.</font>
# - #### <font color='#2D9CDB'>Sakar, C. & Kastro, Y. (2018). Online Shoppers Purchasing Intention Dataset. UCI Machine Learning Repository. https://doi.org/10.24432/</font>

# %% [markdown]
# ## <font color='LightSeaGreen'><u>**2.2 Divisão do Dataset**</font>

# %% [markdown]
# ### <font color='#2D9CDB'>Q22: Explique com suas palavras por que nunca devemos realizar transformações (como escalonamento) no dataset inteiro antes de dividi-lo em treino e teste.</font>

# %% [markdown]
# ### <font color='#2D9CDB'>Q23: Utilizando a função `train_test_split` biblioteca `scikit-learn`, divida as variáveis independentes (`X`) e a variável alvo (`y`) em conjuntos de treinamento (80%) e teste (20%).</font>
# - #### <font color='#2D9CDB'> Lembre-se de fixar uma semente do gerador de números aleatórios (`random_state`) para reprodutibilidade dos resultados.</font>

# %% [markdown]
# ## <font color='LightSeaGreen'><u>**2.3 Codificação de Atributos Categóricos**</u></font>

# %% [markdown]
# ### <font color='#2D9CDB'>Q24: Identifique pelo menos duas variáveis categóricas no seu conjunto de dados de treinamento (`X_train`).</font>

# %% [markdown]
# ### <font color='#2D9CDB'>Q25: Escolha uma das variáveis categóricas nominais identificadas na questão anterior. Selecione essa coluna no seu conjunto de treinamento (`X_train`) e exiba 10 amostras originais.</font>
# - #### <font color='#2D9CDB'> Lembre-se de fixar uma semente do gerador de números aleatórios (`random_state`) para reprodutibilidade dos resultados.</font>

# %% [markdown]
# ### <font color='#2D9CDB'>Q26: Aplique a técnica de `One-Hot Encoding` na variável escolhida utilizando a biblioteca scikit-learn.</font>
# - #### <font color='#2D9CDB'>Lembre-se de utilizar o método `fit_transform` no conjunto de treinamento e apenas `transform` no conjunto de teste.</font>
# - #### <font color='#2D9CDB'>Observação: Ao instanciar o `OneHotEncoder`, utilize os parâmetros `sparse_output=False` (para facilitar a visualização dos dados como um array tradicional) e `handle_unknown='ignore'` (para evitar erros caso o conjunto de teste contenha alguma categoria que não existia no conjunto de treinamento).</font>

# %% [markdown]
# ### <font color='#2D9CDB'>Q27: Exiba as mesmas 10 amostras (agora transformadas) no conjunto de treinamento. Explique brevemente o que aconteceu com a estrutura dos dados originais após a aplicação da técnica.</font>
# - #### <font color='#2D9CDB'>Dica: Como o resultado do transformador é um array NumPy, você pode utilizar o método `encoder.get_feature_names_out()` para descobrir os nomes das novas colunas geradas e facilitar a visualização em um novo DataFrame.</font>

# %% [markdown]
# ## <font color='LightSeaGreen'><u>**2.4 Escalonamento de Atributos**</u></font>

# %% [markdown]
# ### <font color='#2D9CDB'>Q28: Por que algoritmos baseados em distância (como `kNN`) precisam que os dados numéricos estejam escalonados na mesma proporção?</font>

# %% [markdown]
# ### <font color='#2D9CDB'>Q29: Selecione uma coluna numérica contínua de `X_train`. Escreva o nome da característica selecionada abaixo.</font>

# %% [markdown]
# ### <font color='#2D9CDB'>Q30: Calcule e exiba as estatísticas descritivas dessa variável original (Média, Mediana, Desvio Padrão, Mínimo e Máximo).</font>

# %% [markdown]
# ### <font color='#2D9CDB'>Q31: Plote um gráfico mostrando sua distribuição original (Histograma e KDE).</font>

# %% [markdown]
# ### <font color='#2D9CDB'>Q32: Aplique o Escalonamento nesta variável. Você pode escolher entre a Padronização (`StandardScaler`) ou a Normalização (`MinMaxScaler`), ambas da biblioteca scikit-learn.</font>
#
# - #### <font color='#2D9CDB'>Atenção: Realize a transformação e substitua os valores da coluna original no DataFrame (`X_train` e `X_test`) pelos valores escalonados.</font>
# - #### <font color='#2D9CDB'>Lembre-se de utilizar o método `fit_transform` no conjunto de treinamento e apenas `transform` no conjunto de teste.</font>

# %% [markdown]
# ### <font color='#2D9CDB'>Q33: Calcule e exiba as estatísticas descritivas dessa variável transformada (Média, Mediana, Desvio Padrão, Mínimo e Máximo).</font>

# %% [markdown]
# ### <font color='#2D9CDB'>Q34: Plote um gráfico mostrando sua distribuição transformada (Histograma e KDE).</font>

# %% [markdown]
# ### <font color='#2D9CDB'>Q35: Compare os valores e os gráficos antes e depois do escalonamento.</font>
# - #### <font color='#2D9CDB'>O que aconteceu com a média e o desvio padrão (ou com o mínimo e máximo)?</font>
# - #### <font color='#2D9CDB'>O que aconteceu com a escala do eixo X e com o formato da curva no gráfico?</font>

# %% [markdown]
# ## <font color='LightSeaGreen'><u>**2.5 Engenharia de Atributos (Feature Engineering)**</u></font>

# %% [markdown]
# ### <font color='#2D9CDB'>Q36: A partir dos atributos originais, crie uma nova coluna (atributo) no dataset que possa ser informativa para um modelo preditivo. Explique a lógica da sua nova variável.</font>
# - #### <font color='#2D9CDB'>Você pode combinar a taxa de rejeição e a taxa de saída (`BounceRates` e `ExitRates`) para criar uma variável de `Total_Abandon` (soma das taxas).</font>

# %% [markdown]
# ### <font color='#2D9CDB'>Q37: Selecione essa nova coluna no seu conjunto de treinamento (`X_train`) e exiba 10 amostras.</font>
# - #### <font color='#2D9CDB'> Lembre-se de fixar uma semente do gerador de números aleatórios (`random_state`) para reprodutibilidade dos resultados.</font>

# %% [markdown]
# ### <font color='#2D9CDB'>Q38: Calcule a correlação de Pearson dessa nova variável com a variável alvo (`y_train`).</font>
# - #### <font color='#2D9CDB'>A correlação foi negativa, neutra ou positiva? Forte ou fraca?</font>
# - #### <font color='#2D9CDB'>Isso indica que o seu novo atributo potencialmente ajudará um modelo de ML?</font>
# - #### <font color='#2D9CDB'>Importante: Utilize o `LabelEncoder` da biblioteca `scikit-learn` para transformar a variável alvo (`y_train`) em valores numéricos (0 e 1) antes de calcular a correlação.</font>

# %% [markdown]
# ## <font color='LightSeaGreen'><u>**2.6 Extração / Seleção de Atributos**</u></font>

# %% [markdown]
# ### <font color='#2D9CDB'>Q39: Qual a principal diferença conceitual entre Extração de Atributos (ex: `Principal Component Analysis`) e Seleção de Atributos (ex: `Variance Threshold`)? Explique.</font>

# %% [markdown]
# ### <font color='#2D9CDB'>Q40: Aplique a técnica de Análise de Componentes Principais (PCA) nas variáveis numéricas contínuas, excluindo eventuais colunas binárias geradas por codificação categórica.</font>
#
# - #### <font color='#2D9CDB'>a) Inicialmente, instancie o modelo `PCA` da biblioteca `scikit-learn` sem limitar o número de componentes (ou seja, extraindo todos os componentes possíveis) e ajuste-o aos dados de treinamento.</font>
# - #### <font color='#2D9CDB'>b) Crie um gráfico de dispersão (Scatter Plot) mostrando a variância explicada cumulativa em função do número de componentes.</font>
#   - #### <font color='#2D9CDB'>Observação: adicione uma linha de corte horizontal em 95%.</font>
#   - #### <font color='#2D9CDB'>Dica: você pode usar a função `np.cumsum()` sobre o atributo `explained_variance_ratio_` do objeto PCA.</font>
# - #### <font color='#2D9CDB'>c) A partir da análise visual, qual a quantidade mínima de componentes para atingir o critério de 95%? Explique o compromisso envolvido nessa escolha: o que se ganha e o que se perde ao descartar os componentes restantes.</font>

# %% [markdown]
# ### <font color='#2D9CDB'>Q41: Aplique a transformação PCA final utilizando o critério de 95% de variância explicada, sobre o mesmo conjunto de variáveis da questão anterior.</font>
# - #### <font color='#2D9CDB'>a) Instancie um novo modelo PCA com a quantidade de componentes identificada na Q40 e aplique a transformação nos conjuntos de treino e teste.</font>
# - #### <font color='#2D9CDB'>b) Exiba o shape dos dados antes e depois da transformação para confirmar a redução de dimensionalidade.</font>
# - #### <font color='#2D9CDB'>c) Quais são os 3 principais atributos que mais influenciam a primeira Componente Principal (PC1)? Interprete o que esse componente parece representar.</font>
#   - #### <font color='#2D9CDB'>Dica: Analise os `components_` do modelo PCA final, associando cada peso à variável correspondente, e identifique os maiores valores absolutos.</font>
